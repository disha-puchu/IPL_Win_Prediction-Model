# %% [markdown]
# # IPL winner Prediction

# %% [markdown]
# ## Importing Required Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading Datasets

# %%
delivery = pd.read_csv('IPL_Ball_by_Ball_2008_2022.csv')
match = pd.read_csv('IPL_Matches_2008_2022.csv')

# %%
match.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
delivery.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
match.shape, delivery.shape
# Out:
# ((950, 20), (225954, 17))

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Calculating Total Score

# %%
total_score_df = delivery.groupby(['ID','innings']).sum()['total_run'].reset_index()
total_score_df.head()
# Out:
#        ID  innings  total_run
# 0  335982        1        222
# 1  335982        2         82
# 2  335983        1        240
# 3  335983        2        207
# 4  335984        1        129

# %% [markdown]
# ## Extraction of Target Score

# %%
total_score_df = total_score_df[total_score_df['innings'] == 1]
total_score_df.head()
# Out:
#        ID  innings  total_run
# 0  335982        1        222
# 2  335983        1        240
# 4  335984        1        129
# 6  335985        1        165
# 8  335986        1        110

# %% [markdown]
# ## Get required DataFrame by Merging

# %%
match_df = match.merge(total_score_df[['ID','total_run']], on = 'ID')
match_df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# ...

# %% [markdown]
# ## Teams inside our Datasets

# %%
sorted(match_df['Team1'].unique())
# Out:
# ['Chennai Super Kings',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Delhi Daredevils',
#  'Gujarat Lions',
#  'Gujarat Titans',
#  'Kings XI Punjab',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Lucknow Super Giants',
#  'Mumbai Indians',
#  'Pune Warriors',
#  'Punjab Kings',
#  'Rajasthan Royals',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiants',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad']

# %% [markdown]
# ## Teams currently playing IPL

# %%
teams = [
    'Chennai Super Kings',
    'Delhi Capitals',
    'Gujarat Titans',
    'Kolkata Knight Riders',
    'Lucknow Super Giants',
    'Mumbai Indians',
    'Punjab Kings',
    'Rajasthan Royals',
    'Royal Challengers Bangalore',
    'Sunrisers Hyderabad'
]

# %% [markdown]
# ## Replacing the old Team with there new Team name

# %%
match_df['Team1'] = match_df['Team1'].str.replace('Delhi Daredevils','Delhi Capitals')
# match_df['Team1'] = match_df['Team1'].str.replace('Gujarat Lions','Gujarat Titans')
match_df['Team1'] = match_df['Team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['Team1'] = match_df['Team1'].str.replace('Kings XI Punjab','Punjab Kings')

match_df['Team2'] = match_df['Team2'].str.replace('Delhi Daredevils','Delhi Capitals')
# match_df['Team2'] = match_df['Team2'].str.replace('Gujarat Lions','Gujarat Titans')
match_df['Team2'] = match_df['Team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['Team2'] = match_df['Team2'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
delivery['BattingTeam'] = delivery['BattingTeam'].str.replace('Delhi Daredevils','Delhi Capitals')
# delivery['BattingTeam'] = delivery['BattingTeam'].str.replace('Gujarat Lions','Gujarat Titans')
delivery['BattingTeam'] = delivery['BattingTeam'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
delivery['BattingTeam'] = delivery['BattingTeam'].str.replace('Kings XI Punjab','Punjab Kings')

# %% [markdown]
# ## Selecting the the only teams those are currently playing in IPL

# %%
match_df = match_df[match_df['Team1'].isin(teams)]
match_df = match_df[match_df['Team2'].isin(teams)]
match_df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# ...

# %%
delivery = delivery[delivery['BattingTeam'].isin(teams)]
delivery.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %% [markdown]
# ## Getting delivery dataframe by merging delivery match_df and delivery

# %%
delivery_df = match_df[['ID','City','WinningTeam','total_run','Team1','Team2']].merge(delivery, on = 'ID')

# %% [markdown]
# ## Only selecting the 2nd innings for prediction

# %%
delivery_df=delivery_df[delivery_df['innings'] == 2]

# %%
delivery_df.head()
# Out:
#           ID       City     WinningTeam  total_run_x             Team1  \
# 120  1312200  Ahmedabad  Gujarat Titans          130  Rajasthan Royals
# 121  1312200  Ahmedabad  Gujarat Titans          130  Rajasthan Royals
# 122  1312200  Ahmedabad  Gujarat Titans          130  Rajasthan Royals
# 123  1312200  Ahmedabad  Gujarat Titans          130  Rajasthan Royals
# 124  1312200  Ahmedabad  Gujarat Titans          130  Rajasthan Royals
#
#               Team2  innings  overs  ballnumber        batter  ... extra_type  \
# 120  Gujarat Titans        2      0           1       WP Saha  ...        NaN
# 121  Gujarat Titans        2      0           2       WP Saha  ...        NaN
# 122  Gujarat Titans        2      0           3       WP Saha  ...        NaN
# 123  Gujarat Titans        2      0           4  Shubman Gill  ...        NaN
# 124  Gujarat Titans        2      0           5  Shubman Gill  ...        NaN
#
# ...

# %% [markdown]
# ## Getting the Bowling Team

# %%
delivery_df[['Team1','Team2','BattingTeam']].sample(10)
# Out:
#                               Team1                  Team2  \
# 107943             Rajasthan Royals         Mumbai Indians
# 172726  Royal Challengers Bangalore    Sunrisers Hyderabad
# 118688               Mumbai Indians       Rajasthan Royals
# 101856             Rajasthan Royals         Mumbai Indians
# 155899                 Punjab Kings    Chennai Super Kings
# 134413          Sunrisers Hyderabad       Rajasthan Royals
# 122931             Rajasthan Royals         Delhi Capitals
# 61403           Sunrisers Hyderabad    Chennai Super Kings
# 9580                 Gujarat Titans  Kolkata Knight Riders
# 82857   Royal Challengers Bangalore    Sunrisers Hyderabad
#
#                         BattingTeam
# 107943             Rajasthan Royals
# 172726          Sunrisers Hyderabad
# 118688               Mumbai Indians
# 101856             Rajasthan Royals
# 155899                 Punjab Kings
# 134413          Sunrisers Hyderabad
# 122931             Rajasthan Royals
# ...

# %%
delivery_df['BowlingTeam'] = np.where(
    delivery_df['BattingTeam'] == delivery_df['Team2'], 
    delivery_df['Team1'], delivery_df['Team2'])

# %%
delivery_df.tail()
# Out:
#             ID       City            WinningTeam  total_run_x  \
# 198930  335982  Bangalore  Kolkata Knight Riders          222
# 198931  335982  Bangalore  Kolkata Knight Riders          222
# 198932  335982  Bangalore  Kolkata Knight Riders          222
# 198933  335982  Bangalore  Kolkata Knight Riders          222
# 198934  335982  Bangalore  Kolkata Knight Riders          222
#
#                               Team1                  Team2  innings  overs  \
# 198930  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198931  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198932  Royal Challengers Bangalore  Kolkata Knight Riders        2     14
# 198933  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
# 198934  Royal Challengers Bangalore  Kolkata Knight Riders        2     15
#
#         ballnumber    batter  ... batsman_run extras_run total_run_y  \
# ...

# %% [markdown]
# ## Calculating *current_score*, *runs_left*, *balls_left*, *wicket_left*, *current_runrate* & *required_runrate*

# %%
delivery_df['current_score'] = delivery_df.groupby('ID')['total_run_y'].cumsum().astype('int')

# %%
delivery_df['runs_left'] = delivery_df['total_run_x'] - delivery_df['current_score'] + 1

# %%
delivery_df['balls_left'] = 120 - (delivery_df['overs']*6 + delivery_df['ballnumber'])

# %%
delivery_df['player_out'] = delivery_df['player_out'].fillna('0')
delivery_df['player_out'] = delivery_df['player_out'].apply(lambda x: x if x == '0' else '1')
delivery_df['player_out'] = delivery_df['player_out'].astype('int')
wickets = delivery_df.groupby('ID')['player_out'].cumsum().values
delivery_df['wicket_left'] = 10 - wickets

# %%
delivery_df['crr'] = delivery_df['current_score']/((120 - delivery_df['balls_left']) / 6)

# %%
delivery_df['rrr'] = delivery_df['runs_left'] / ((delivery_df['balls_left']) / 6)

# %%
delivery_df.head()
# Out:
#           ID       City     WinningTeam  total_run_x             Team1  \
# 120  1312200  Ahmedabad  Gujarat Titans          130  Rajasthan Royals
# 121  1312200  Ahmedabad  Gujarat Titans          130  Rajasthan Royals
# 122  1312200  Ahmedabad  Gujarat Titans          130  Rajasthan Royals
# 123  1312200  Ahmedabad  Gujarat Titans          130  Rajasthan Royals
# 124  1312200  Ahmedabad  Gujarat Titans          130  Rajasthan Royals
#
#               Team2  innings  overs  ballnumber        batter  ... kind  \
# 120  Gujarat Titans        2      0           1       WP Saha  ...  NaN
# 121  Gujarat Titans        2      0           2       WP Saha  ...  NaN
# 122  Gujarat Titans        2      0           3       WP Saha  ...  NaN
# 123  Gujarat Titans        2      0           4  Shubman Gill  ...  NaN
# 124  Gujarat Titans        2      0           5  Shubman Gill  ...  NaN
#
#     fielders_involved     BattingTeam       BowlingTeam  current_score  \
# ...

# %% [markdown]
# ## Calculating result of the match *(win/loss)*

# %%
delivery_df['result'] = delivery_df.apply(lambda row: 1 if row['BattingTeam'] == row['WinningTeam'] else 0,axis = 1)

# %% [markdown]
# ## Extracting the required columns to train our model

# %%
final_df = delivery_df[['City', 'BattingTeam', 'BowlingTeam', 'runs_left', 'balls_left','wicket_left','total_run_x','crr','rrr','result']]
final_df
# Out:
#              City                  BattingTeam            BowlingTeam  \
# 120     Ahmedabad               Gujarat Titans       Rajasthan Royals
# 121     Ahmedabad               Gujarat Titans       Rajasthan Royals
# 122     Ahmedabad               Gujarat Titans       Rajasthan Royals
# 123     Ahmedabad               Gujarat Titans       Rajasthan Royals
# 124     Ahmedabad               Gujarat Titans       Rajasthan Royals
# ...           ...                          ...                    ...
# 198930  Bangalore  Royal Challengers Bangalore  Kolkata Knight Riders
# 198931  Bangalore  Royal Challengers Bangalore  Kolkata Knight Riders
# 198932  Bangalore  Royal Challengers Bangalore  Kolkata Knight Riders
# 198933  Bangalore  Royal Challengers Bangalore  Kolkata Knight Riders
# 198934  Bangalore  Royal Challengers Bangalore  Kolkata Knight Riders
#
#         runs_left  balls_left  wicket_left  total_run_x       crr        rrr  \
# ...

# %% [markdown]
# ## Handelling the inifinity and Nan values

# %%
final_df = final_df[final_df['balls_left'] != 0]
final_df.dropna(inplace = True)
final_df
# Out:
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_19712\3790670495.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace = True)
#              City                  BattingTeam            BowlingTeam  \
# 120     Ahmedabad               Gujarat Titans       Rajasthan Royals
# 121     Ahmedabad               Gujarat Titans       Rajasthan Royals
# 122     Ahmedabad               Gujarat Titans       Rajasthan Royals
# 123     Ahmedabad               Gujarat Titans       Rajasthan Royals
# 124     Ahmedabad               Gujarat Titans       Rajasthan Royals
# ...           ...                          ...                    ...
# 198930  Bangalore  Royal Challengers Bangalore  Kolkata Knight Riders
# 198931  Bangalore  Royal Challengers Bangalore  Kolkata Knight Riders
# ...

# %% [markdown]
# ## Saving the final_df as csv file for UI/server design using streamlit

# %%
final_df.to_csv('final_dataset.csv', index = False)

# %% [markdown]
# ## Suffle the datasets to prevent from bias

# %%
final_df = final_df.sample(final_df.shape[0])
final_df.head()
# Out:
#              City                  BattingTeam                  BowlingTeam  \
# 82871   Bangalore  Royal Challengers Bangalore          Sunrisers Hyderabad
# 57765      Mumbai          Chennai Super Kings               Mumbai Indians
# 102134  Bangalore          Sunrisers Hyderabad  Royal Challengers Bangalore
# 69704   Hyderabad                 Punjab Kings          Sunrisers Hyderabad
# 55118     Kolkata               Delhi Capitals        Kolkata Knight Riders
#
#         runs_left  balls_left  wicket_left  total_run_x        crr        rrr  \
# 82871         126          71           10          208  10.163265  10.647887
# 57765          56          12            3          170   6.388889  28.000000
# 102134        101          82           10          166  10.421053   7.390244
# 69704         133         119           10          132   0.000000   6.705882
# 55118          31          24            8          178   9.250000   7.750000
#
#         result
# 82871        0
# ...

# %% [markdown]
# ## Extracting X and y to train our model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 191)

# %%
X = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]

# %% [markdown]
# ## Performing train_test_split

# %%
X_train
# Out:
#                   City                  BattingTeam            BowlingTeam  \
# 110950       Bangalore  Royal Challengers Bangalore           Punjab Kings
# 179746  Port Elizabeth                 Punjab Kings  Kolkata Knight Riders
# 97668          Chennai        Kolkata Knight Riders    Chennai Super Kings
# 177884     East London               Delhi Capitals         Mumbai Indians
# 175934          Durban          Sunrisers Hyderabad         Delhi Capitals
# ...                ...                          ...                    ...
# 87673       Chandigarh                 Punjab Kings         Mumbai Indians
# 163040         Chennai               Mumbai Indians    Chennai Super Kings
# 143895         Kolkata        Kolkata Knight Riders       Rajasthan Royals
# 189705       Hyderabad          Sunrisers Hyderabad         Mumbai Indians
# 101869       Ahmedabad             Rajasthan Royals         Mumbai Indians
#
# ...

# %% [markdown]
# ## Implementation of ColumnTransformer, OneHotEncoder and Pipeline using *LogisticRegression*

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

encode = ColumnTransformer([
    ('encode', OneHotEncoder(drop='first'), ['City', 'BattingTeam', 'BowlingTeam'])
], remainder='passthrough')

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
pipe = Pipeline(steps = [
    ('encode',encode),
    ('model',LogisticRegression(solver = 'liblinear'))
])

# %% [markdown]
# ## Training the Model and predicting output

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('encode',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('encode',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['City', 'BattingTeam',
#                                                    'BowlingTeam'])])),
# ...

# %%
y_pred = pipe.predict(X_test)

# %% [markdown]
# ## Accuracy Score

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8202197066859979

# %% [markdown]
# ## Predict Probability

# %%
pipe.predict_proba(X_test)[np.random.randint(0, X_test.shape[0])]
# Out:
# array([0.61205501, 0.38794499])

# %% [markdown]
# ## Saving the model using pickle

# %%
import pickle
pickle.dump(pipe,open('IPL_model.pkl', 'wb'))

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

encode = ColumnTransformer([
    ('encode', OneHotEncoder(drop='first'), ['City', 'BattingTeam', 'BowlingTeam'])
], remainder='passthrough')

pipe = Pipeline(steps = [
    ('encode',encode),
    ('model',RandomForestClassifier())
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

accuracy_score(y_test,y_pred)
# Out:
# 0.9985501589248871

# %%
pipe.predict_proba(X_test)[np.random.randint(0, X_test.shape[0])]
# Out:
# array([0., 1.])

# %%
import pickle
pickle.dump(pipe,open('IPL_model2.pkl', 'wb'))
